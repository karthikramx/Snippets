# %% [markdown]
# ### Why Pandas?
# - Flexibility with python
# - better than excel to work with big data

# %%
import pandas as pd

data = pd.read_csv('data/pokemon_data.csv')
#read from excel files
data_excel = pd.read_excel('data/pokemon_data.xlsx')
#readind from text files
data_text = pd.read_csv('data/pokemon_data.txt', delimiter='\t')

# %%
# Display first 5 rows of the data
data_excel.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# print all the columns
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# get values of a single column
# can also be written as --? data.Name and data['Name']
data['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Get multiple columns
data[['Name','Attack','Speed']]
# Out:
#                       Name  Attack  Speed
# 0                Bulbasaur      49     45
# 1                  Ivysaur      62     60
# 2                 Venusaur      82     80
# 3    VenusaurMega Venusaur     100     80
# 4               Charmander      52     65
# ..                     ...     ...    ...
# 795                Diancie     100     50
# 796    DiancieMega Diancie     160    110
# 797    HoopaHoopa Confined     110     70
# 798     HoopaHoopa Unbound     160     80
# 799              Volcanion     110     70
#
# [800 rows x 3 columns]

# %%
# Get first 5 rows of multiple columns 
data[['Name','Attack','Speed']][0:5]
# Out:
#                     Name  Attack  Speed
# 0              Bulbasaur      49     45
# 1                Ivysaur      62     60
# 2               Venusaur      82     80
# 3  VenusaurMega Venusaur     100     80
# 4             Charmander      52     65

# %%
# integer location based extraction - iloc : integer location
data.iloc[0:4]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# extracting value of a specific cell is down as follows - to get value of 0th row and 1st column
data.iloc[0,1]
# Out:
# 'Bulbasaur'

# %%
# iterating through rows
for index, row in data.iterrows():
    print(index, row[['Name']])
# Out:
# 0 Name    Bulbasaur
# Name: 0, dtype: object
# 1 Name    Ivysaur
# Name: 1, dtype: object
# 2 Name    Venusaur
# Name: 2, dtype: object
# 3 Name    VenusaurMega Venusaur
# Name: 3, dtype: object
# 4 Name    Charmander
# Name: 4, dtype: object
# 5 Name    Charmeleon
# Name: 5, dtype: object
# 6 Name    Charizard
# Name: 6, dtype: object
# 7 Name    CharizardMega Charizard X
# Name: 7, dtype: object
# 8 Name    CharizardMega Charizard Y
# Name: 8, dtype: object
# 9 Name    Squirtle
# Name: 9, dtype: object
# 10 Name    Wartortle
# Name: 10, dtype: object
# 11 Name    Blastoise
# Name: 11, dtype: object
# 12 Name    BlastoiseMega Blastoise
# Name: 12, dtype: object
# 13 Name    Caterpie
# Name: 13, dtype: object
# 14 Name    Metapod
# Name: 14, dtype: object
# 15 Name    Butterfree
# Name: 15, dtype: object
# 16 Name    Weedle
# Name: 16, dtype: object
# 17 Name    Kakuna
# Name: 17, dtype: object
# 18 Name    Beedrill
# Name: 18, dtype: object
# 19 Name    BeedrillMega Beedrill
# ...

# %%
# locating information bases on textual information
data.loc[data['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
# get basic stats on data frame
data.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# sorting values in a data frame
data.sort_values(['Name']).head(5)
# Out:
#        #                     Name   Type 1 Type 2  HP  Attack  Defense  \
# 510  460                Abomasnow    Grass    Ice  90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass    Ice  90     132      105
# 68    63                     Abra  Psychic    NaN  25      20       15
# 392  359                    Absol     Dark    NaN  65     130       60
# 393  359          AbsolMega Absol     Dark    NaN  65     150       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False

# %%
# sorting values by multiple columns
data.sort_values(['Name','Defense'], ascending=False).head(5)
# Out:
#        #              Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 794  718  Zygarde50% Forme  Dragon  Ground  108     100      121       81
# 695  634          Zweilous    Dark  Dragon   72      85       70       65
# 46    41             Zubat  Poison  Flying   40      45       35       30
# 631  570             Zorua    Dark     NaN   40      65       40       80
# 632  571           Zoroark    Dark     NaN   60     105       60      120
#
#      Sp. Def  Speed  Generation  Legendary
# 794       95     95           6       True
# 695       70     58           5      False
# 46        40     55           1      False
# 631       40     65           5      False
# 632       60    105           5      False

# %%
# sorting using ascendiing mask
data.sort_values(['Name','HP'], ascending=[1,0]).head(5)
# Out:
#        #                     Name   Type 1 Type 2  HP  Attack  Defense  \
# 510  460                Abomasnow    Grass    Ice  90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass    Ice  90     132      105
# 68    63                     Abra  Psychic    NaN  25      20       15
# 392  359                    Absol     Dark    NaN  65     130       60
# 393  359          AbsolMega Absol     Dark    NaN  65     150       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False

# %%
# making changes to the tqble, adding new columns
data['Total'] = data['Attack'] + data['Defense']

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     98
# 1       80     60           1      False    125
# 2      100     80           1      False    165
# 3      120     80           1      False    223
# 4       50     65           1      False     95

# %%
# droping a specific column from a data frame
data.drop('Total', inplace=True, axis=1)

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# performing row operations using iloc
data['Total'] = data.iloc[:,4:10].sum(axis=1)

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
# Rearrranging columns in a data frame
cols = list(data.columns)
data = data[cols[0:4] + [cols[-1]] + cols[5:12]]

# %%
data.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison    318      49       49       65
# 1  2                Ivysaur  Grass  Poison    405      62       63       80
# 2  3               Venusaur  Grass  Poison    525      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison    625     100      123      122
# 4  4             Charmander   Fire     NaN    309      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# saving back as a csv file
data.to_csv('data/modified_pokemon_data.csv', index = False)
data.to_excel('data/modified_pokemon_data.xlsx',index = False)
data.to_csv('data/modified_pokemon_data.txt',index = False, sep = '\t')

# %% [markdown]
# #### Filtering Data

# %%
# use & instead of and
new_df = data.loc[(data['Type 1'] == 'Grass') & (data['Type 2'] == 'Poison')]
new_df.head(5)
# Out:
#      #                   Name Type 1  Type 2  Total  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass  Poison    318      49       49       65
# 1    2                Ivysaur  Grass  Poison    405      62       63       80
# 2    3               Venusaur  Grass  Poison    525      82       83      100
# 3    3  VenusaurMega Venusaur  Grass  Poison    625     100      123      122
# 48  43                 Oddish  Grass  Poison    320      50       55       75
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 48       65     30           1      False

# %% [markdown]
# #### Reset Index

# %%
new_df.reset_index(drop = True, inplace=True)

# %%
new_df.head(10)
# Out:
#     #                   Name Type 1  Type 2  Total  Attack  Defense  Sp. Atk  \
# 0   1              Bulbasaur  Grass  Poison    318      49       49       65
# 1   2                Ivysaur  Grass  Poison    405      62       63       80
# 2   3               Venusaur  Grass  Poison    525      82       83      100
# 3   3  VenusaurMega Venusaur  Grass  Poison    625     100      123      122
# 4  43                 Oddish  Grass  Poison    320      50       55       75
# 5  44                  Gloom  Grass  Poison    395      65       70       85
# 6  45              Vileplume  Grass  Poison    490      80       85      110
# 7  69             Bellsprout  Grass  Poison    300      75       35       70
# 8  70             Weepinbell  Grass  Poison    390      90       50       85
# 9  71             Victreebel  Grass  Poison    490     105       65      100
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
# extracting names the contain a certain text
data[~data['Name'].str.contains('Mega')].head(5)
# Out:
#    #        Name Type 1  Type 2  Total  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525      82       83      100      100
# 4  4  Charmander   Fire     NaN    309      52       43       60       50
# 5  5  Charmeleon   Fire     NaN    405      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     65           1      False
# 5     80           1      False

# %% [markdown]
# #### Passing regular expressions

# %%
import re

# %%
data.loc[ data['Type 1'].str.contains('file|grass', flags=re.I, regex=True) ]
# re.I refers to Ignore
# Out:
#        #                   Name Type 1    Type 2  Total  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318      49       49
# 1      2                Ivysaur  Grass    Poison    405      62       63
# 2      3               Venusaur  Grass    Poison    525      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625     100      123
# 48    43                 Oddish  Grass    Poison    320      50       55
# ..   ...                    ...    ...       ...    ...     ...      ...
# 718  650                Chespin  Grass       NaN    313      61       65
# 719  651              Quilladin  Grass       NaN    405      78       95
# 720  652             Chesnaught  Grass  Fighting    530     107      122
# 740  672                 Skiddo  Grass       NaN    350      65       48
# 741  673                 Gogoat  Grass       NaN    531     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# stating with a centain alphabets
data.loc[ data['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True) ]
# Out:
#        #                 Name    Type 1    Type 2  Total  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying    251      45       40
# 21    17            Pidgeotto    Normal    Flying    349      60       55
# 22    18              Pidgeot    Normal    Flying    479      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579      80       80
# 30    25              Pikachu  Electric       NaN    320      55       40
# 136  127               Pinsir       Bug       NaN    500     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying    600     155      120
# 186  172                Pichu  Electric       NaN    205      40       15
# 219  204               Pineco       Bug       NaN    290      65       90
# 239  221            Piloswine       Ice    Ground    450     100       80
# 438  393               Piplup     Water       NaN    314      51       53
# 558  499              Pignite      Fire  Fighting    418      93       55
# ...

# %% [markdown]
# #### Conditional Statements

# %%
data.loc[data['Type 1'] == 'Fire', 'Type 1' ] = 'Flamer'
data.head(10)
# Out:
#    #                       Name  Type 1  Type 2  Total  Attack  Defense  \
# 0  1                  Bulbasaur   Grass  Poison    318      49       49
# 1  2                    Ivysaur   Grass  Poison    405      62       63
# 2  3                   Venusaur   Grass  Poison    525      82       83
# 3  3      VenusaurMega Venusaur   Grass  Poison    625     100      123
# 4  4                 Charmander  Flamer     NaN    309      52       43
# 5  5                 Charmeleon  Flamer     NaN    405      64       58
# 6  6                  Charizard  Flamer  Flying    534      84       78
# 7  6  CharizardMega Charizard X  Flamer  Dragon    634     130      111
# 8  6  CharizardMega Charizard Y  Flamer  Flying    634     104       78
# 9  7                   Squirtle   Water     NaN    314      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# ...

# %%
data.loc[ data['Total'] > 500, ['Legendary','Generation']] = 'TEST VALUE'

# %%
data =  pd.read_csv('data/modified_pokemon_data.csv')

# %% [markdown]
# #### Aggregate Statistics

# %%
# checking which type of type 1 pokemon has the average attack value
data.groupby('Type 1').mean().sort_values('Attack',ascending=False)
# Out:
#                    #       Total      Attack     Defense    Sp. Atk  \
# Type 1
# Dragon    474.375000  550.531250  112.125000   86.375000  96.843750
# Fighting  363.851852  416.444444   96.777778   65.925926  53.111111
# Ground    356.281250  437.500000   95.750000   84.843750  56.468750
# Rock      392.727273  453.750000   92.863636  100.795455  63.340909
# Steel     442.851852  487.703704   92.703704  126.370370  67.518519
# Dark      461.354839  445.741935   88.387097   70.225806  74.645161
# Fire      327.403846  458.076923   84.769231   67.769231  88.980769
# Flying    677.750000  485.000000   78.750000   66.250000  94.250000
# Poison    251.785714  399.142857   74.678571   68.821429  60.428571
# Water     303.089286  430.455357   74.151786   72.946429  74.812500
# Ghost     486.500000  439.562500   73.781250   81.187500  79.343750
# Normal    319.173469  401.683673   73.469388   59.846939  55.816327
# Grass     344.871429  421.142857   73.214286   70.800000  77.500000
# ...

# %%
data.groupby('Type 1').sum().sort_values('Attack',ascending=False)
# Out:
#               #  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Type 1
# Water     33946  48211    8305     8170     8379     7898   7388         320
# Normal    31279  39365    7200     5865     5470     6245   7012         299
# Grass     24141  29480    5125     4956     5425     4930   4335         235
# Bug       23080  26146    4897     4880     3717     4471   4256         222
# Fire      17025  23820    4408     3524     4627     3755   3871         167
# Rock      17280  19965    4086     4435     2787     3321   2460         152
# Psychic   21706  27129    4073     3858     5609     4918   4645         193
# Dragon    15180  17617    3588     2764     3099     2843   2657         124
# Ground    11401  14000    3064     2715     1807     2008   2045         101
# Electric  15994  19510    3040     2917     3961     3243   3718         144
# Dark      14302  13818    2740     2177     2314     2155   2361         125
# ...

# %%
data.groupby('Type 1').count()
# Out:
#             #  Name  Type 2  Total  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52     69      69       69       69       69     69
# Dark       31    31      21     31      31       31       31       31     31
# Dragon     32    32      21     32      32       32       32       32     32
# Electric   44    44      17     44      44       44       44       44     44
# Fairy      17    17       2     17      17       17       17       17     17
# Fighting   27    27       7     27      27       27       27       27     27
# Fire       52    52      24     52      52       52       52       52     52
# Flying      4     4       2      4       4        4        4        4      4
# Ghost      32    32      22     32      32       32       32       32     32
# Grass      70    70      37     70      70       70       70       70     70
# Ground     32    32      19     32      32       32       32       32     32
# ...

# %%
data['count'] = 1

# %%
# grouping by two column types
data.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# #### Working with large amounts of data
